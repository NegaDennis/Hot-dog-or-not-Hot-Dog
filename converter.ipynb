# %%
import os
import sys

# %%
# Mounting drive
from google.colab import drive
if os.path.ismount('/content/drive') == False:
    drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Setting working directories
model_path = '/content/drive/MyDrive/Github/Medium/1A - Hot dog or not hot dog/runs/hot_dog_or_not_hot_dog_v001_2025-09-23_14-45'
os.chdir(model_path)  # latest model run folder

print(os.getcwd())
# Out:
# /content/drive/MyDrive/Github/Medium/1A - Hot dog or not hot dog/runs/hot_dog_or_not_hot_dog_v001_2025-09-23_14-45

# %%
# Loading model
import tensorflow as tf
from keras.models import load_model

model = load_model("hot_dog_or_not_hot_dog.keras")

# %%
# Converting model to tf.lite
converter = tf.lite.TFLiteConverter.from_keras_model(model)

converter.optimizations = [tf.lite.Optimize.DEFAULT]

lite_model = converter.convert()

with open("lite_model.tflite","wb") as f:
  f.write(lite_model)
# Out:
# Saved artifact at '/tmp/tmp8x2z4t9a'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 128, 128, 3), dtype=tf.float32, name='input_layer_2')
# Output Type:
#   TensorSpec(shape=(None, 1), dtype=tf.float32, name=None)
# Captures:
#   134105202440720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134105202442064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134105196904720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134105196905296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134105196905104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134105196905680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134105196907216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134105196906640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   134105196907984: TensorSpec(shape=(), dtype=tf.resource, name=None)
# ...
