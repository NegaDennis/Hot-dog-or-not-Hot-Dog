# %% [markdown]
# # House-keeping

# %%
#Loading basic libraries
import numpy as np
import matplotlib.pyplot as plt
import random
import os
import math
import pandas as pd

#Loading ML libraries
from tensorflow import keras
import tensorflow as tf

## Data preparation
from tensorflow.keras.utils import to_categorical

# %%
# Mounting drive
from google.colab import drive
import os
if os.path.ismount('/content/drive'):
    print("Google Drive is already mounted.")
else:
    drive.mount('/content/drive')
    print("Google Drive is succesfully mounted")
# Out:
# Google Drive is already mounted.

# %%
# to work with ipynb
# !pip install importnb

# Arrange directories
import sys, os

project_root = '/content/drive/MyDrive/Github/1A - Hot dog or not hot dog'
scr = os.path.join(project_root, 'scr')

os.chdir(project_root)  # main.py will be here (using this notebook for testing scripts for now)
sys.path.append(scr)    # script folder

print(os.getcwd())
# Out:
# Requirement already satisfied: importnb in /usr/local/lib/python3.12/dist-packages (2023.11.1)
# /content/drive/MyDrive/Github/1A - Hot dog or not hot dog

# %%
# Dealing with config
import json

with open('config.json') as f:
    cfg = json.load(f)

# importing config vars (yes, i know. but it works. refactor later.)
seed = cfg["seed"]
model = cfg["model"]
validation_split = cfg["validation_split"]
train_hot_dog_path = cfg["data_paths"]["train_hot_dog"]
test_hot_dog_path = cfg["data_paths"]["test_hot_dog"]
train_not_hot_dog_path = cfg["data_paths"]["train_not_hot_dog"]
test_not_hot_dog_path = cfg["data_paths"]["test_not_hot_dog"]
img_rows = cfg["data_parameters"]["img_rows"]
img_cols = cfg["data_parameters"]["img_cols"]
num_classes = cfg["data_parameters"]["num_classes"]
channels = cfg["data_parameters"]["channels"]
class_names = cfg["data_parameters"]["class_names"]
export_dir = cfg["export"]["export_dir"]
model_name = cfg["export"]["model_name"]
optimizer = cfg["optimize"]["optimizer"]
learning_rate = cfg["optimize"]["learning_rate"]
loss = cfg["optimize"]["loss"]
metrics = cfg["optimize"]["metrics"]
epochs = cfg["optimize"]["epochs"]
batch_size = cfg["optimize"]["batch_size"]
weight_decay = cfg["optimize"]["weight_decay"]
beta_1 = cfg["optimize"]["beta_1"]
beta_2 = cfg["optimize"]["beta_2"]
epsilon = cfg["optimize"]["epsilon"]

# %%
# scr (use .ipynb files for now)
from importnb import Notebook
with Notebook():
    import preprocessing
    import models
    from optimizer import get_optimizer
    import export

# %%
# ensure replicability
os.environ['PYTHONHASHSEED'] = str(seed)
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
# Show all physical devices TF can see
print("Physical devices detected:", tf.config.list_physical_devices())

# Quick check if GPU is available
print("Is built with GPU support:", tf.test.is_built_with_cuda())
print("Is GPU available to TF:", tf.config.list_physical_devices('GPU'))

# Which device ops are placed on by default
print("Default device:", tf.test.gpu_device_name())
# Out:
# Physical devices detected: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Is built with GPU support: True
# Is GPU available to TF: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Default device: /device:GPU:0

# %% [markdown]
# <a id = "cell_Preprocessing"></a>
# # 1. Data loading and preparation

# %%
# building train and test datasets
train_folder = [
    (train_hot_dog_path, "hot_dog"),
    (train_not_hot_dog_path, "not_hot_dog")
]

test_folder = [
    (test_hot_dog_path, "hot_dog"),
    (test_not_hot_dog_path, "not_hot_dog")
]
train_data = preprocessing.preprocess_image(train_folder,image_size= (img_rows,img_cols))
test_data = preprocessing.preprocess_image(test_folder,image_size= (img_rows,img_cols))

# %%
# Converting image to arrays
result = preprocessing.image_to_array(train_data,test_data)
x_train = result['x_train']
y_train = result['y_train']
x_test = result['x_test']
y_test = result['y_test']

# %%
# Normalize data
result = preprocessing.image_data_normalizer(x_train,x_test,scale_type="0-1")
x_train = result['x_train']
x_test = result['x_test']

# %%
# encoding labels
# Create a NumPy array with category strings
categories = np.array(['hot_dog','not_hot_dog'])

# Create a mapping from category strings to integers
category_map = {'hot_dog': 1, 'not_hot_dog': 0}

# Encode the categories
y_train = np.array([category_map[category] for category in y_train])
y_test = np.array([category_map[category] for category in y_test])

# %%
# Reshape images for processing
x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channels)
x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channels)

print('Train shape: x=', x_train.shape, ', y=', y_train.shape)
print('Test shape: x=', x_test.shape, ', y=', y_test.shape)
# Out:
# Train shape: x= (4242, 128, 128, 3) , y= (4242,)
# Test shape: x= (400, 128, 128, 3) , y= (400,)

# %% [markdown]
# # Modellings

# %%
# Keras callbacks (stop if val_loss doesn't improve after 20 epochs)
from tensorflow.keras.callbacks import TensorBoard, Callback, EarlyStopping

keras_callbacks = [EarlyStopping(monitor='val_loss', patience=20, verbose=0)]

# %%
# Choose model
model_func = getattr(models, model)
model = model_func()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
# Getting optimizer
optimize = get_optimizer(cfg["optimize"])

# Compiling model
model.compile(
    optimizer=optimize,
    loss=loss,
    metrics=metrics
)

# Fitting and recording training history
history = model.fit(x_train, y_train,
      batch_size=batch_size,
      epochs=epochs,
      verbose=2,
      validation_data=(x_test, y_test),
      validation_split=validation_split,
      callbacks=keras_callbacks)
# Out:
# Epoch 1/100
# 133/133 - 16s - 118ms/step - accuracy: 0.5240 - loss: 2.0457 - val_accuracy: 0.5000 - val_loss: 1.9506
# Epoch 2/100
# 133/133 - 15s - 116ms/step - accuracy: 0.5377 - loss: 1.7419 - val_accuracy: 0.5000 - val_loss: 1.7672
# Epoch 3/100
# 133/133 - 10s - 76ms/step - accuracy: 0.5752 - loss: 1.6186 - val_accuracy: 0.5050 - val_loss: 1.6275
# Epoch 4/100
# 133/133 - 10s - 78ms/step - accuracy: 0.5684 - loss: 1.5565 - val_accuracy: 0.5000 - val_loss: 1.7638
# Epoch 5/100
# 133/133 - 10s - 75ms/step - accuracy: 0.5705 - loss: 1.4842 - val_accuracy: 0.5000 - val_loss: 1.6296
# Epoch 6/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6106 - loss: 1.4228 - val_accuracy: 0.5050 - val_loss: 1.5325
# Epoch 7/100
# 133/133 - 10s - 77ms/step - accuracy: 0.5771 - loss: 1.4112 - val_accuracy: 0.5000 - val_loss: 1.5106
# Epoch 8/100
# 133/133 - 10s - 76ms/step - accuracy: 0.6245 - loss: 1.3447 - val_accuracy: 0.5050 - val_loss: 1.4291
# Epoch 9/100
# 133/133 - 10s - 78ms/step - accuracy: 0.5990 - loss: 1.3286 - val_accuracy: 0.5000 - val_loss: 1.4587
# Epoch 10/100
# 133/133 - 10s - 75ms/step - accuracy: 0.6202 - loss: 1.2849 - val_accuracy: 0.5175 - val_loss: 1.3814
# Epoch 11/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6370 - loss: 1.2530 - val_accuracy: 0.5025 - val_loss: 1.6483
# Epoch 12/100
# 133/133 - 8s - 61ms/step - accuracy: 0.6400 - loss: 1.2338 - val_accuracy: 0.5200 - val_loss: 1.3553
# Epoch 13/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6601 - loss: 1.2223 - val_accuracy: 0.5225 - val_loss: 1.3987
# Epoch 14/100
# 133/133 - 8s - 60ms/step - accuracy: 0.6179 - loss: 1.2062 - val_accuracy: 0.5175 - val_loss: 1.4212
# Epoch 15/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6558 - loss: 1.1610 - val_accuracy: 0.5225 - val_loss: 1.5115
# Epoch 16/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6561 - loss: 1.1342 - val_accuracy: 0.5275 - val_loss: 1.5118
# Epoch 17/100
# 133/133 - 10s - 78ms/step - accuracy: 0.6193 - loss: 1.1442 - val_accuracy: 0.5650 - val_loss: 1.1726
# Epoch 18/100
# 133/133 - 10s - 76ms/step - accuracy: 0.6554 - loss: 1.0827 - val_accuracy: 0.5525 - val_loss: 1.3298
# Epoch 19/100
# 133/133 - 8s - 60ms/step - accuracy: 0.6610 - loss: 1.0817 - val_accuracy: 0.5475 - val_loss: 1.1949
# Epoch 20/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6697 - loss: 1.0571 - val_accuracy: 0.5400 - val_loss: 1.4369
# Epoch 21/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6233 - loss: 1.0913 - val_accuracy: 0.5450 - val_loss: 1.1667
# Epoch 22/100
# 133/133 - 10s - 75ms/step - accuracy: 0.6157 - loss: 1.0898 - val_accuracy: 0.5325 - val_loss: 1.1475
# Epoch 23/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6657 - loss: 1.0095 - val_accuracy: 0.5475 - val_loss: 1.2801
# Epoch 24/100
# 133/133 - 8s - 61ms/step - accuracy: 0.6499 - loss: 1.0381 - val_accuracy: 0.5375 - val_loss: 1.1095
# Epoch 25/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6865 - loss: 0.9743 - val_accuracy: 0.5500 - val_loss: 1.2619
# Epoch 26/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6813 - loss: 0.9724 - val_accuracy: 0.5675 - val_loss: 1.2316
# Epoch 27/100
# 133/133 - 8s - 59ms/step - accuracy: 0.6879 - loss: 0.9434 - val_accuracy: 0.5625 - val_loss: 1.1781
# Epoch 28/100
# 133/133 - 10s - 79ms/step - accuracy: 0.6782 - loss: 0.9548 - val_accuracy: 0.5500 - val_loss: 1.2116
# Epoch 29/100
# 133/133 - 10s - 76ms/step - accuracy: 0.6919 - loss: 0.9287 - val_accuracy: 0.5600 - val_loss: 1.2663
# Epoch 30/100
# 133/133 - 8s - 60ms/step - accuracy: 0.7011 - loss: 0.9201 - val_accuracy: 0.5775 - val_loss: 1.1255
# Epoch 31/100
# 133/133 - 10s - 76ms/step - accuracy: 0.6815 - loss: 0.9361 - val_accuracy: 0.5725 - val_loss: 1.0571
# Epoch 32/100
# 133/133 - 10s - 77ms/step - accuracy: 0.7103 - loss: 0.8761 - val_accuracy: 0.5700 - val_loss: 1.1829
# Epoch 33/100
# 133/133 - 10s - 78ms/step - accuracy: 0.6987 - loss: 0.8731 - val_accuracy: 0.5700 - val_loss: 1.2319
# Epoch 34/100
# 133/133 - 10s - 75ms/step - accuracy: 0.7056 - loss: 0.8464 - val_accuracy: 0.5775 - val_loss: 1.2651
# Epoch 35/100
# 133/133 - 10s - 78ms/step - accuracy: 0.6945 - loss: 0.8751 - val_accuracy: 0.5850 - val_loss: 1.1012
# Epoch 36/100
# 133/133 - 8s - 59ms/step - accuracy: 0.6973 - loss: 0.8530 - val_accuracy: 0.5600 - val_loss: 0.9473
# Epoch 37/100
# 133/133 - 10s - 78ms/step - accuracy: 0.7008 - loss: 0.8260 - val_accuracy: 0.5775 - val_loss: 1.1425
# Epoch 38/100
# 133/133 - 8s - 62ms/step - accuracy: 0.7098 - loss: 0.8478 - val_accuracy: 0.5800 - val_loss: 1.1482
# Epoch 39/100
# 133/133 - 10s - 77ms/step - accuracy: 0.5971 - loss: 1.0095 - val_accuracy: 0.5575 - val_loss: 0.9148
# Epoch 40/100
# 133/133 - 8s - 61ms/step - accuracy: 0.6264 - loss: 0.8919 - val_accuracy: 0.5725 - val_loss: 0.9181
# Epoch 41/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6384 - loss: 0.8762 - val_accuracy: 0.5675 - val_loss: 0.9654
# Epoch 42/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6662 - loss: 0.8690 - val_accuracy: 0.5950 - val_loss: 0.9482
# Epoch 43/100
# 133/133 - 8s - 62ms/step - accuracy: 0.5533 - loss: 0.9584 - val_accuracy: 0.5500 - val_loss: 0.9110
# Epoch 44/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6084 - loss: 0.8818 - val_accuracy: 0.5975 - val_loss: 0.9096
# Epoch 45/100
# 133/133 - 10s - 78ms/step - accuracy: 0.5413 - loss: 0.9693 - val_accuracy: 0.6050 - val_loss: 0.8924
# Epoch 46/100
# 133/133 - 10s - 76ms/step - accuracy: 0.5853 - loss: 0.9000 - val_accuracy: 0.6100 - val_loss: 0.8953
# Epoch 47/100
# 133/133 - 10s - 78ms/step - accuracy: 0.6141 - loss: 0.8878 - val_accuracy: 0.5975 - val_loss: 0.8944
# Epoch 48/100
# 133/133 - 10s - 75ms/step - accuracy: 0.6245 - loss: 0.8776 - val_accuracy: 0.5975 - val_loss: 0.8801
# Epoch 49/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6037 - loss: 0.8804 - val_accuracy: 0.5875 - val_loss: 0.9011
# Epoch 50/100
# 133/133 - 8s - 62ms/step - accuracy: 0.6139 - loss: 0.9543 - val_accuracy: 0.5000 - val_loss: 1.5330
# Epoch 51/100
# 133/133 - 10s - 77ms/step - accuracy: 0.5752 - loss: 0.9085 - val_accuracy: 0.5300 - val_loss: 0.9211
# Epoch 52/100
# 133/133 - 8s - 63ms/step - accuracy: 0.6443 - loss: 0.8379 - val_accuracy: 0.5350 - val_loss: 1.1191
# Epoch 53/100
# 133/133 - 10s - 76ms/step - accuracy: 0.6735 - loss: 0.8227 - val_accuracy: 0.5400 - val_loss: 1.0153
# Epoch 54/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6813 - loss: 0.8039 - val_accuracy: 0.5600 - val_loss: 0.9828
# Epoch 55/100
# 133/133 - 10s - 78ms/step - accuracy: 0.6980 - loss: 0.7939 - val_accuracy: 0.5825 - val_loss: 0.9487
# Epoch 56/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6881 - loss: 0.8147 - val_accuracy: 0.6075 - val_loss: 0.9296
# Epoch 57/100
# 133/133 - 10s - 75ms/step - accuracy: 0.7030 - loss: 0.7816 - val_accuracy: 0.5875 - val_loss: 0.9141
# Epoch 58/100
# 133/133 - 8s - 62ms/step - accuracy: 0.6638 - loss: 0.8128 - val_accuracy: 0.6400 - val_loss: 0.8656
# Epoch 59/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6902 - loss: 0.7933 - val_accuracy: 0.6075 - val_loss: 0.9033
# Epoch 60/100
# 133/133 - 8s - 62ms/step - accuracy: 0.7030 - loss: 0.8021 - val_accuracy: 0.5900 - val_loss: 1.0645
# Epoch 61/100
# 133/133 - 10s - 76ms/step - accuracy: 0.6704 - loss: 0.7914 - val_accuracy: 0.6100 - val_loss: 0.9096
# Epoch 62/100
# 133/133 - 10s - 78ms/step - accuracy: 0.7093 - loss: 0.7897 - val_accuracy: 0.5850 - val_loss: 0.9395
# Epoch 63/100
# 133/133 - 10s - 76ms/step - accuracy: 0.6843 - loss: 0.7834 - val_accuracy: 0.5125 - val_loss: 1.1984
# Epoch 64/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6386 - loss: 0.8483 - val_accuracy: 0.5100 - val_loss: 0.9706
# Epoch 65/100
# 133/133 - 8s - 60ms/step - accuracy: 0.6594 - loss: 0.7914 - val_accuracy: 0.6150 - val_loss: 0.8823
# Epoch 66/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6834 - loss: 0.8182 - val_accuracy: 0.5275 - val_loss: 0.9617
# Epoch 67/100
# 133/133 - 10s - 78ms/step - accuracy: 0.6504 - loss: 0.8158 - val_accuracy: 0.5950 - val_loss: 0.9974
# Epoch 68/100
# 133/133 - 10s - 76ms/step - accuracy: 0.6938 - loss: 0.7677 - val_accuracy: 0.5925 - val_loss: 0.8677
# Epoch 69/100
# 133/133 - 8s - 61ms/step - accuracy: 0.7020 - loss: 0.8177 - val_accuracy: 0.5900 - val_loss: 0.8580
# Epoch 70/100
# 133/133 - 10s - 75ms/step - accuracy: 0.7126 - loss: 0.7454 - val_accuracy: 0.6150 - val_loss: 0.8706
# Epoch 71/100
# 133/133 - 10s - 77ms/step - accuracy: 0.7089 - loss: 0.7442 - val_accuracy: 0.6350 - val_loss: 0.8529
# Epoch 72/100
# 133/133 - 8s - 60ms/step - accuracy: 0.7225 - loss: 0.7163 - val_accuracy: 0.6250 - val_loss: 0.8588
# Epoch 73/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6978 - loss: 0.7381 - val_accuracy: 0.6050 - val_loss: 0.8353
# Epoch 74/100
# 133/133 - 8s - 60ms/step - accuracy: 0.7350 - loss: 0.7357 - val_accuracy: 0.5925 - val_loss: 0.9181
# Epoch 75/100
# 133/133 - 10s - 77ms/step - accuracy: 0.7086 - loss: 0.7495 - val_accuracy: 0.5400 - val_loss: 0.8666
# Epoch 76/100
# 133/133 - 10s - 78ms/step - accuracy: 0.5724 - loss: 0.8416 - val_accuracy: 0.5700 - val_loss: 0.8385
# Epoch 77/100
# 133/133 - 10s - 76ms/step - accuracy: 0.6462 - loss: 0.7839 - val_accuracy: 0.6150 - val_loss: 0.8767
# Epoch 78/100
# 133/133 - 8s - 60ms/step - accuracy: 0.6488 - loss: 0.7799 - val_accuracy: 0.5650 - val_loss: 0.8561
# Epoch 79/100
# 133/133 - 10s - 77ms/step - accuracy: 0.6858 - loss: 0.7405 - val_accuracy: 0.5950 - val_loss: 0.9198
# Epoch 80/100
# 133/133 - 10s - 76ms/step - accuracy: 0.7056 - loss: 0.7373 - val_accuracy: 0.5975 - val_loss: 0.9320
# Epoch 81/100
# 133/133 - 10s - 77ms/step - accuracy: 0.7110 - loss: 0.7212 - val_accuracy: 0.5125 - val_loss: 1.0318
# Epoch 82/100
# 133/133 - 10s - 78ms/step - accuracy: 0.6358 - loss: 0.8044 - val_accuracy: 0.5875 - val_loss: 0.9642
# Epoch 83/100
# 133/133 - 10s - 75ms/step - accuracy: 0.7112 - loss: 0.7375 - val_accuracy: 0.6000 - val_loss: 0.9244
# Epoch 84/100
# 133/133 - 10s - 78ms/step - accuracy: 0.7082 - loss: 0.7115 - val_accuracy: 0.6275 - val_loss: 0.8556
# Epoch 85/100
# 133/133 - 10s - 77ms/step - accuracy: 0.7188 - loss: 0.7016 - val_accuracy: 0.6125 - val_loss: 0.8201
# Epoch 86/100
# 133/133 - 8s - 60ms/step - accuracy: 0.7070 - loss: 0.7059 - val_accuracy: 0.5975 - val_loss: 0.9677
# Epoch 87/100
# 133/133 - 8s - 57ms/step - accuracy: 0.7390 - loss: 0.6805 - val_accuracy: 0.6125 - val_loss: 0.9609
# Epoch 88/100
# 133/133 - 8s - 60ms/step - accuracy: 0.6374 - loss: 0.8395 - val_accuracy: 0.5750 - val_loss: 0.8332
# Epoch 89/100
# 133/133 - 10s - 76ms/step - accuracy: 0.6827 - loss: 0.7282 - val_accuracy: 0.6000 - val_loss: 0.9303
# Epoch 90/100
# 133/133 - 8s - 57ms/step - accuracy: 0.6954 - loss: 0.7249 - val_accuracy: 0.6075 - val_loss: 0.7821
# Epoch 91/100
# 133/133 - 10s - 77ms/step - accuracy: 0.7082 - loss: 0.6934 - val_accuracy: 0.6000 - val_loss: 0.9908
# Epoch 92/100
# 133/133 - 10s - 78ms/step - accuracy: 0.7287 - loss: 0.7034 - val_accuracy: 0.5725 - val_loss: 0.8671
# Epoch 93/100
# 133/133 - 10s - 76ms/step - accuracy: 0.7037 - loss: 0.7088 - val_accuracy: 0.6050 - val_loss: 0.9481
# Epoch 94/100
# 133/133 - 10s - 76ms/step - accuracy: 0.7049 - loss: 0.7016 - val_accuracy: 0.6275 - val_loss: 0.9307
# Epoch 95/100
# 133/133 - 10s - 75ms/step - accuracy: 0.7341 - loss: 0.6648 - val_accuracy: 0.6100 - val_loss: 0.9002
# Epoch 96/100
# 133/133 - 8s - 56ms/step - accuracy: 0.7409 - loss: 0.6539 - val_accuracy: 0.6025 - val_loss: 1.0485
# Epoch 97/100
# 133/133 - 8s - 57ms/step - accuracy: 0.7504 - loss: 0.6600 - val_accuracy: 0.6100 - val_loss: 1.0008
# Epoch 98/100
# 133/133 - 10s - 75ms/step - accuracy: 0.7591 - loss: 0.6373 - val_accuracy: 0.5975 - val_loss: 1.1542
# Epoch 99/100
# 133/133 - 10s - 77ms/step - accuracy: 0.7362 - loss: 0.6497 - val_accuracy: 0.6175 - val_loss: 1.1208
# Epoch 100/100
# 133/133 - 7s - 56ms/step - accuracy: 0.7581 - loss: 0.6336 - val_accuracy: 0.6025 - val_loss: 1.0911

# %%
# Preliminary evaluation on training data
train_score = model.evaluate(x_train, y_train, verbose=0)
print('Train loss:', round(train_score[0], 4))
print('Train accuracy:', round(train_score[1], 4), '\n')

# Preliminary evaluation on test data
test_score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss:', round(test_score[0], 4))
print('Test accuracy:', round(test_score[1], 4))
# Out:
# Train loss: 0.6303
# Train accuracy: 0.7459
#
# Test loss: 1.0911
# Test accuracy: 0.6025

# %% [markdown]
# # Evaluate performance

# %%
## Evaluation
from sklearn.metrics import classification_report
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
# Make predictions on the test set
y_pred = model.predict(x_test)

# Convert the predicted labels to continuous-multioutput format
y_pred = np.round(y_pred)

# Calculate the kappa score
kappa = cohen_kappa_score(y_test, y_pred)
print("The result of Kappa is :", round(kappa, 3))

# Generate the classification report
report = classification_report(y_test, y_pred, target_names = class_names)

# Print the report
print("The result of the classification report is: \n ",report)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# The result of Kappa is : 0.205
# The result of the classification report is:
#                 precision    recall  f1-score   support
#
#      hot_dog       0.60      0.60      0.60       200
#  not_hot_dog       0.60      0.60      0.60       200
#
#     accuracy                           0.60       400
#    macro avg       0.60      0.60      0.60       400
# weighted avg       0.60      0.60      0.60       400

# %%
#Generating confusion matrix
cm = confusion_matrix(
    y_test,
    y_pred)

# Create a ConfusionMatrixDisplay object
display = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=class_names)

# Create a figure with a larger size
fig = plt.figure(figsize=(5, 5))

# Create a subplot within the figure
ax = fig.subplots()

# Plot the confusion matrix as a heatmap
display.plot(ax=ax)

# Show the plot
plt.show()

# %%
#Plotting learning history
#Platform prepping
def plot_hist(h, xsize=6, ysize=5):
    # Prepare plotting
    fig_size = plt.rcParams["figure.figsize"]
    plt.rcParams["figure.figsize"] = [xsize, ysize]

    # Get training and validation keys
    ks = list(h.keys())
    n2 = math.floor(len(ks)/2)
    train_keys = ks[0:n2]
    valid_keys = ks[n2:2*n2]

    # summarize history for different metrics
    for i in range(n2):
        plt.plot(h[train_keys[i]])
        plt.plot(h[valid_keys[i]])
        plt.title('Training vs Validation '+train_keys[i])
        plt.ylabel(train_keys[i])
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Validation'], loc='upper left')
        plt.draw()
        plt.show()

    return

#Execute
plot_hist(pd.DataFrame(history.history))

# %% [markdown]
# # Export model and result

# %%
# Some final note about this version of the model before exporting. will also be exported into a note.txt file
note = ""

# %%
# only save model trained on full train set (some test runs are done on "small" dataset to check scripts)
export.save_model_and_metrics(model=model,
                              history=history,
                              x_test=x_test,
                              y_test=y_test,
                              export_dir=export_dir,
                              model_name=model_name,
                              config=cfg,
                              note=note)
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# Saved model, metrics and config to /content/drive/MyDrive/Github/1A - Hot dog or not hot dog/models/hot_dog_or_not_hot_dog_v001_2025-09-14_15-47
